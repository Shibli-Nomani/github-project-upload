# %% [markdown]
# #Upload vscode project using git-bash

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2>Open Project Folder</h2>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Project Upload Directly from folder using git-scm

# %% [markdown]
# ![image.png](data:image/png;base64,...)
